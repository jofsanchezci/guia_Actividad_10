# %% [markdown]
# **Taller 1: Uso de Pandas**
#
# Nombre: Joaquin F Sanchez
#
# Cedula: 888888

# %%
# !pip install sodapy

# %%
#Punto 1
#Cargue el dataset disponible en 
#https://www.datos.gov.co/Econom-a-y- Finanzas/Tasa-de-Cambio-Representativa-del-Mercado-TRM/32sa-8pi3
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sodapy import Socrata
cliente=Socrata('www.datos.gov.co', None)
result=cliente.get("32sa-8pi3")
df=pd.DataFrame.from_records(result)
df.head()
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
#      valor unidad            vigenciadesde            vigenciahasta
# 0  4761.64    COP  2022-12-22T00:00:00.000  2022-12-22T00:00:00.000
# 1  4781.28    COP  2022-12-20T00:00:00.000  2022-12-20T00:00:00.000
# 2  4802.48    COP  2022-12-17T00:00:00.000  2022-12-19T00:00:00.000
# 3  4836.24    COP  2022-12-13T00:00:00.000  2022-12-13T00:00:00.000
# 4  4815.99    COP  2022-12-10T00:00:00.000  2022-12-12T00:00:00.000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   valor          1000 non-null   object
#  1   unidad         1000 non-null   object
#  2   vigenciadesde  1000 non-null   object
#  3   vigenciahasta  1000 non-null   object
# dtypes: object(4)
# memory usage: 31.4+ KB

# %%
#columna_numerica = pd.to_numeric(datos['limite_menor_cuantia'], errors='coerce')
#columna_numerica = columna_numerica.dropna().astype(float)
valor=pd.to_numeric(df['valor'],errors='coerce')
print(valor)
# Out:
# 0      4761.64
# 1      4781.28
# 2      4802.48
# 3      4836.24
# 4      4815.99
#         ...
# 995    1978.63
# 996    1993.85
# 997    1998.60
# 998    2017.38
# 999    2034.86
# Name: valor, Length: 1000, dtype: float64

# %%
#Punto 2
#Calcular
#a. Media
#b. Mediana
#c. Desviación estándar
#d. Máximo
#e. Mínimo
#f. Máximo
#g. Rango
print('El valor de la media es: ',round(np.mean(valor),3))
print('El valor de la mediana es: ',round(np.median(valor),3))
print('El valor de la desviacion estandar es: ',round(np.std(valor),3))
print('El valor del máximo es: ',round(np.max(valor),3))
print('El valor del mínimo es: ',round(np.min(valor),3))
print('El valor del rango es: ',round(np.max(valor),3)-round(np.min(valor),3))
# Out:
# El valor de la media es:  3042.377
# El valor de la mediana es:  2972.525
# El valor de la desviacion estandar es:  730.324
# El valor del máximo es:  5061.21
# El valor del mínimo es:  1846.12
# El valor del rango es:  3215.09

# %%
#Punto 3
#Presentar el resumen de los datos numéricos
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   valor          1000 non-null   object
#  1   unidad         1000 non-null   object
#  2   vigenciadesde  1000 non-null   object
#  3   vigenciahasta  1000 non-null   object
# dtypes: object(4)
# memory usage: 31.4+ KB

# %%
df['Valor_n']=valor
df
# Out:
#        valor unidad            vigenciadesde            vigenciahasta  Valor_n
# 0    4761.64    COP  2022-12-22T00:00:00.000  2022-12-22T00:00:00.000  4761.64
# 1    4781.28    COP  2022-12-20T00:00:00.000  2022-12-20T00:00:00.000  4781.28
# 2    4802.48    COP  2022-12-17T00:00:00.000  2022-12-19T00:00:00.000  4802.48
# 3    4836.24    COP  2022-12-13T00:00:00.000  2022-12-13T00:00:00.000  4836.24
# 4    4815.99    COP  2022-12-10T00:00:00.000  2022-12-12T00:00:00.000  4815.99
# ..       ...    ...                      ...                      ...      ...
# 995  1978.63    COP  2014-03-26T00:00:00.000  2014-03-26T00:00:00.000  1978.63
# 996  1993.85    COP  2014-03-22T00:00:00.000  2014-03-25T00:00:00.000  1993.85
# 997   1998.6    COP  2014-03-21T00:00:00.000  2014-03-21T00:00:00.000  1998.60
# 998  2017.38    COP  2014-03-20T00:00:00.000  2014-03-20T00:00:00.000  2017.38
# 999  2034.86    COP  2014-03-19T00:00:00.000  2014-03-19T00:00:00.000  2034.86
#
# [1000 rows x 5 columns]

# %%
df.describe()
# Out:
#            Valor_n
# count  1000.000000
# mean   3042.376510
# std     730.689006
# min    1846.120000
# 25%    2500.497500
# 50%    2972.525000
# 75%    3646.340000
# max    5061.210000

# %%
#Punto 4
#Presentar la información general del dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   valor          1000 non-null   object
#  1   unidad         1000 non-null   object
#  2   vigenciadesde  1000 non-null   object
#  3   vigenciahasta  1000 non-null   object
#  4   Valor_n        1000 non-null   float64
# dtypes: float64(1), object(4)
# memory usage: 39.2+ KB

# %% [markdown]
# **Análisis del Data Set.**
#
# Se evidencia que el data set original no cuenta con los tipos datos semesjantes a la descripción de la pagina de datos abierto. Dado que la columana "valor" no es de tipo numero sino de tipo "object".
#
# La operación que se se realizó fue hacer una conversión a numeros flotantes y luego adjuntarla al DataFrame

# %%
#Punto 5
#Hacer dos representaciones graficas que sean acordes a la naturaleza de los datos
df.hist(bins=10)
plt.title('Histograma de la variación del Dolar')
plt.xlabel('Pesos')
plt.show()

# %%
df.plot()
plt.title('Grafica de la variación del dolar sin ordenar')
plt.xlabel('Tiempo')
plt.ylabel('Pesos')
plt.grid()
plt.show()

# %%
#Ordenar las fechas y valores del data Frame
data_o=df.sort_values(by=['vigenciadesde'])
valores=list(data_o['Valor_n'])
plt.plot(valores,'r--')
plt.title('Variación hitorica del dolar')
plt.xlabel('Tiempo')
plt.ylabel('Pesos')
plt.grid()
plt.show()

# %%
print(data_o.head(1))
# Out:
#        valor unidad            vigenciadesde            vigenciahasta  Valor_n
# 999  2034.86    COP  2014-03-19T00:00:00.000  2014-03-19T00:00:00.000  2034.86

# %%
print(data_o.tail())
# Out:
#      valor unidad            vigenciadesde            vigenciahasta  Valor_n
# 4  4815.99    COP  2022-12-10T00:00:00.000  2022-12-12T00:00:00.000  4815.99
# 3  4836.24    COP  2022-12-13T00:00:00.000  2022-12-13T00:00:00.000  4836.24
# 2  4802.48    COP  2022-12-17T00:00:00.000  2022-12-19T00:00:00.000  4802.48
# 1  4781.28    COP  2022-12-20T00:00:00.000  2022-12-20T00:00:00.000  4781.28
# 0  4761.64    COP  2022-12-22T00:00:00.000  2022-12-22T00:00:00.000  4761.64

# %%
#Punto 6
#Usando Socrata, Cargue un dataset que se encuentre en el portal de datos públicos
#de Colombia
#se usa un data set del paruqe automotor del departamento de Boyaca
cliente2=Socrata('www.datos.gov.co', None)
result=cliente2.get("874t-i57z")
df_auto=pd.DataFrame.from_records(result)
df_auto.head()
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
#           municipio        clase    marca modelo carroceria pasajeros  \
# 0  ACUERDOS DE PAGO      CAMPERO   SUZUKI   1997    CARPADO         5
# 1  ACUERDOS DE PAGO  MOTOCICLETA   YAMAHA   2022      CROSS         2
# 2  ACUERDOS DE PAGO    AUTOMOVIL    MAZDA   1989      SEDAN         5
# 3           ALMEIDA    AUTOMOVIL  HYUNDAI   2023      SEDAN         5
# 4           ALMEIDA  MOTOCICLETA   YAMAHA   2022      SPORT         2
#
#      servicio  estado                          linea tonelaje cilindraje  \
# 0  PARTICULAR  ACTIVO                            NaN      NaN        NaN
# 1  PARTICULAR  ACTIVO  MOTOCICLETA - GPD150-A (NMAX)        0        155
# 2  PARTICULAR  ACTIVO                            626        0       2000
# 3  PARTICULAR  ACTIVO          ACCENT ADVANCE MT RBT        0       1591
# 4  PARTICULAR  ACTIVO                         YAMAHA        0        149
#
#   blindaje importado puertas
# 0      NaN       NaN     NaN
# 1      NaN       NaN     NaN
# 2        N         N       4
# 3      NaN       NaN     NaN
# 4      NaN       NaN     NaN

# %%
#Punto 7
#Realice las tareas de limpieza y transformación necesarias
#Liempiza Quitar datos nulos
df_auto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   municipio   1000 non-null   object
#  1   clase       1000 non-null   object
#  2   marca       1000 non-null   object
#  3   modelo      1000 non-null   object
#  4   carroceria  999 non-null    object
#  5   pasajeros   1000 non-null   object
#  6   servicio    1000 non-null   object
#  7   estado      1000 non-null   object
#  8   linea       949 non-null    object
#  9   tonelaje    996 non-null    object
#  10  cilindraje  999 non-null    object
#  11  blindaje    847 non-null    object
#  12  importado   836 non-null    object
#  13  puertas     861 non-null    object
# dtypes: object(14)
# memory usage: 109.5+ KB

# %%
#Eliminar filas con dato nulos
df_auto=df_auto.dropna(axis=0, how='any')
df_auto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 801 entries, 2 to 999
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   municipio   801 non-null    object
#  1   clase       801 non-null    object
#  2   marca       801 non-null    object
#  3   modelo      801 non-null    object
#  4   carroceria  801 non-null    object
#  5   pasajeros   801 non-null    object
#  6   servicio    801 non-null    object
#  7   estado      801 non-null    object
#  8   linea       801 non-null    object
#  9   tonelaje    801 non-null    object
#  10  cilindraje  801 non-null    object
#  11  blindaje    801 non-null    object
#  12  importado   801 non-null    object
#  13  puertas     801 non-null    object
# dtypes: object(14)
# memory usage: 93.9+ KB

# %%
df_auto.describe()
# Out:
#            municipio        clase  marca modelo carroceria pasajeros  \
# count            801          801    801    801        801       801
# unique             4            8     50     51         20        15
# top     CHIQUINQUIRA  MOTOCICLETA  SIGMA   2008   CABINADO         2
# freq             772          374    117    128        162       379
#
#           servicio  estado      linea tonelaje cilindraje blindaje importado  \
# count          801     801        801      801        801      801       801
# unique           2       1        179       14         58        2         4
# top     PARTICULAR  ACTIVO  SIN LINEA        0        150        N         N
# freq           796     801        193      699        174      750       542
#
#        puertas
# count      801
# unique       6
# top          0
# freq       374

# %%
df_auto.head()
# Out:
#            municipio      clase       marca modelo carroceria pasajeros  \
# 2   ACUERDOS DE PAGO  AUTOMOVIL       MAZDA   1989      SEDAN         5
# 10         AQUITANIA    CAMPERO   CHEVROLET   1989   CABINADO         5
# 11         AQUITANIA    CAMPERO  MITSUBISHI   1992   CABINADO         5
# 12         AQUITANIA  CAMIONETA   CHEVROLET   2004     ESTACA         2
# 13         AQUITANIA  CAMIONETA   CHEVROLET   1993     ESTACA         0
#
#       servicio  estado        linea tonelaje cilindraje blindaje importado  \
# 2   PARTICULAR  ACTIVO          626        0       2000        N         N
# 10  PARTICULAR  ACTIVO      TROOPER        0       2600        N         N
# 11  PARTICULAR  ACTIVO      MONTERO        0       2600        N         N
# 12  PARTICULAR  ACTIVO  LUV TFR LWB        1       2500        N         N
# 13  PARTICULAR  ACTIVO      LUV TFR        1          1        N         N
#
#    puertas
# 2        4
# 10       2
# 11       2
# 12       2
# 13       2

# %%
#Revisar si hay registros duplicados
print(df_auto.duplicated())
# Out:
# 2      False
# 10     False
# 11     False
# 12     False
# 13     False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999     True
# Length: 801, dtype: bool

# %%
df_auto.drop_duplicates(inplace = True)
df_auto
# Out:
#             municipio      clase        marca modelo carroceria pasajeros  \
# 2    ACUERDOS DE PAGO  AUTOMOVIL        MAZDA   1989      SEDAN         5
# 10          AQUITANIA    CAMPERO    CHEVROLET   1989   CABINADO         5
# 11          AQUITANIA    CAMPERO   MITSUBISHI   1992   CABINADO         5
# 12          AQUITANIA  CAMIONETA    CHEVROLET   2004     ESTACA         2
# 13          AQUITANIA  CAMIONETA    CHEVROLET   1993     ESTACA         0
# ..                ...        ...          ...    ...        ...       ...
# 994      CHIQUINQUIRA  CAMIONETA   MITSUBISHI   1998     ESTACA         0
# 995      CHIQUINQUIRA    CAMPERO  JEEP WILLYS   1998   CABINADO         5
# 996      CHIQUINQUIRA  AUTOMOVIL      RENAULT   1998      SEDAN         5
# 997      CHIQUINQUIRA  AUTOMOVIL        MAZDA   1998      SEDAN         5
# 998      CHIQUINQUIRA  CAMIONETA         FORD   1997   CABINADO         5
#
#        servicio  estado        linea tonelaje cilindraje blindaje importado  \
# 2    PARTICULAR  ACTIVO          626        0       2000        N         N
# 10   PARTICULAR  ACTIVO      TROOPER        0       2600        N         N
# 11   PARTICULAR  ACTIVO      MONTERO        0       2600        N         N
# 12   PARTICULAR  ACTIVO  LUV TFR LWB        1       2500        N         N
# 13   PARTICULAR  ACTIVO      LUV TFR        1          1        N         N
# ..          ...     ...          ...      ...        ...      ...       ...
# 994  PARTICULAR  ACTIVO        L-200        1          1        N         N
# 995  PARTICULAR  ACTIVO     CHEROKEE        0       4000        0         1
# 996  PARTICULAR  ACTIVO          R19        0       1400        N         N
# 997  PARTICULAR  ACTIVO      ALLEGRO        0       1600        N         N
# 998  PARTICULAR  ACTIVO     EXPLORER        0       4000        0         0
#
#     puertas
# 2         4
# 10        2
# 11        2
# 12        2
# 13        2
# ..      ...
# 994       2
# 995       2
# 996       4
# 997       4
# 998       2
#
# [509 rows x 14 columns]

# %%
df_auto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 509 entries, 2 to 998
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   municipio   509 non-null    object
#  1   clase       509 non-null    object
#  2   marca       509 non-null    object
#  3   modelo      509 non-null    object
#  4   carroceria  509 non-null    object
#  5   pasajeros   509 non-null    object
#  6   servicio    509 non-null    object
#  7   estado      509 non-null    object
#  8   linea       509 non-null    object
#  9   tonelaje    509 non-null    object
#  10  cilindraje  509 non-null    object
#  11  blindaje    509 non-null    object
#  12  importado   509 non-null    object
#  13  puertas     509 non-null    object
# dtypes: object(14)
# memory usage: 59.6+ KB

# %%
#Punto 8
#Presentar el dataset, mostrando datos estadísticos y gráficas
df_auto.head()
var=list((df_auto['modelo']))
modelo=[]
for i in range(len(var)):
  modelo.append(int(var[i]))

modelo_a=np.array(modelo)
print('La media de los modelos es: ', np.mean(modelo_a))
# Out:
# La media de los modelos es:  1990.2888015717092

# %% [markdown]
# **Analisis de los modelos del parque automotor de Boyaca.**
#
# La media es 1994, lo cual indica que en promedio los automoviles en boyaca tiene más de vente y cinco (25) años de uso. Las implicaciones en el medio ambiente pueden ser notorias ya que la quema de combustibles fosiles contribuye a una mauor huella de carbon

# %%
#Grafica del histograma de modelos
plt.hist(modelo_a, bins=10)
plt.axvline(np.mean(modelo_a), ymin=0.0, ymax=0.9,color='r')
plt.title('Histograma de los modelos del parque automotor')
plt.grid()
plt.show()

# %%
#Graficas el diagrama de caja de los modelos
plt.boxplot(modelo_a)
plt.title('Diagram de caja para el modelo')
plt.ylabel('Años')
plt.grid()
plt.show()

# %%
#Analisis de las clases del parque automotor
df_clase=df_auto[['clase']]
df_clase.head()
# Out:
#         clase
# 2   AUTOMOVIL
# 10    CAMPERO
# 11    CAMPERO
# 12  CAMIONETA
# 13  CAMIONETA

# %%
df_clase.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 509 entries, 2 to 998
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   clase   509 non-null    object
# dtypes: object(1)
# memory usage: 8.0+ KB

# %%
df_clase.tail()
# Out:
#          clase
# 994  CAMIONETA
# 995    CAMPERO
# 996  AUTOMOVIL
# 997  AUTOMOVIL
# 998  CAMIONETA

# %%
lista_clase=list(df_clase['clase'])
for i in lista_clase:
  print(i)

# %%
df_clase.describe()
# Out:
#           clase
# count       509
# unique        8
# top     CAMPERO
# freq        144

# %%
#Vamos a contar las diferentes clases de automoviles
def contar(n, vec):
  '''Para esta funcion n es el numero a contar y vec es la lista donde contar '''
  count=0
  for i in vec:
    if i==n:
      count+=1
  return count

# %%
print('AUTOMOVIL aparece: ',contar('AUTOMOVIL', lista_clase))
print('CAMPERO aparece: ',contar('CAMPERO', lista_clase))
print('CAMIONETA aparece: ',contar('CAMIONETA', lista_clase))
print('CAMION aparece: ',contar('CAMION', lista_clase))
print('MOTOCICLETA aparece: ',contar('MOTOCICLETA', lista_clase))
print('VOLQUETA aparece: ',contar('VOLQUETA', lista_clase))
print('BUSETA aparece: ',contar('BUSETA', lista_clase))
print('MICRO BUS aparece: ',contar('MICRO BUS', lista_clase))

aux=[contar('AUTOMOVIL', lista_clase), contar('CAMPERO', lista_clase),contar('CAMIONETA', lista_clase),
     contar('CAMION', lista_clase),contar('MOTOCICLETA', lista_clase), contar('VOLQUETA', lista_clase),
     contar('BUSETA', lista_clase) , contar('MICRO BUS', lista_clase)]
print('La suma total es de: ', sum(aux))
# Out:
# AUTOMOVIL aparece:  121
# CAMPERO aparece:  144
# CAMIONETA aparece:  96
# CAMION aparece:  18
# MOTOCICLETA aparece:  119
# VOLQUETA aparece:  7
# BUSETA aparece:  3
# MICRO BUS aparece:  1
# La suma total es de:  509

# %%
num_clase=[]
for i in range(len(lista_clase)):
  num_clase.append(contar(lista_clase[i],lista_clase))

print(num_clase)
print(len(num_clase))
# Out:
# [121, 144, 144, 96, 96, 18, 144, 119, 119, 119, 144, 119, 119, 96, 119, 119, 119, 121, 119, 7, 119, 96, 121, 18, 121, 121, 3, 18, 121, 119, 119, 119, 144, 121, 1, 121, 96, 96, 121, 144, 96, 18, 144, 144, 144, 144, 144, 18, 119, 121, 121, 121, 18, 121, 119, 96, 121, 144, 144, 121, 144, 144, 144, 18, 144, 96, 121, 18, 144, 144, 144, 144, 144, 144, 96, 144, 121, 144, 144, 121, 144, 96, 144, 144, 121, 96, 121, 121, 96, 121, 121, 121, 96, 121, 96, 121, 18, 121, 96, 144, 144, 96, 144, 144, 121, 96, 121, 121, 96, 121, 121, 121, 144, 144, 144, 121, 96, 96, 144, 96, 144, 121, 144, 144, 121, 144, 121, 96, 18, 121, 121, 144, 144, 144, 121, 144, 121, 96, 121, 144, 96, 121, 96, 121, 7, 121, 96, 96, 144, 144, 96, 96, 121, 144, 121, 96, 144, 144, 96, 96, 119, 119, 119, 119, 121, 7, 96, 96, 144, 144, 144, 121, 96, 96, 96, 18, 121, 96, 96, 144, 144, 96, 121, 144, 144, 18, 96, 144, 144, 144, 96, 144, 144, 144, 144, 96, 121, 121, 121, 121, 144, 96, 96, 96, 121, 96, 96, 144, 144, 144, 96, 144, 144, 18, 144, 144, 96, 121, 144, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 119, 121, 119, 119, 119, 119, 119, 119, 119, 96, 144, 121, 144, 96, 144, 144, 144, 96, 121, 96, 144, 144, 121, 119, 144, 96, 121, 144, 96, 121, 96, 144, 144, 144, 144, 144, 96, 144, 96, 144, 96, 96, 144, 96, 144, 144, 144, 121, 121, 144, 121, 121, 121, 144, 144, 96, 144, 144, 144, 121, 144, 121, 144, 121, 96, 96, 121, 144, 121, 144, 144, 96, 144, 121, 121, 144, 96, 144, 144, 144, 121, 121, 144, 96, 144, 144, 121, 96, 96, 96, 121, 121, 121, 121, 144, 144, 121, 121, 121, 96, 121, 121, 121, 121, 121, 121, 121, 144, 121, 121, 121, 144, 144, 144, 144, 18, 96, 144, 18, 144, 144, 96, 144, 121, 121, 96, 96, 144, 121, 121, 18, 121, 121, 121, 144, 121, 144, 144, 144, 121, 3, 144, 96, 7, 7, 96, 7, 96, 121, 18, 96, 96, 144, 96, 7, 144, 144, 18, 121, 121, 121, 144, 96, 144, 121, 144, 121, 121, 3, 96, 121, 144, 96, 121, 96, 96, 144, 96, 144, 121, 144, 96, 96, 96, 121, 121, 96, 121, 144, 121, 121, 96, 144, 144, 96, 144, 121, 121, 96]
# 509

# %%
#Diagrama de Barras
categoria=['AUTO','CAM','CAMI','CAMIO', 'MOTO','VOL','BUS','MICRO']
plt.bar(categoria,aux,width=0.8, color='lime')
plt.xlabel('Clases')
plt.ylabel('Veces que se repiten')
plt.title('Análisi sobre las clases de automotores')
plt.grid()
plt.show()

# %%
len(num_clase)
# Out:
# 509

# %%
#aux_=pd.Series(num_clase)
#df_clase['Repite']=aux_
#df_clase

# %%
#Punto 9
#Se debe incluir mínimo una tabla pivote y una agrupación
df_auto.head()
# Out:
#            municipio      clase       marca modelo carroceria pasajeros  \
# 2   ACUERDOS DE PAGO  AUTOMOVIL       MAZDA   1989      SEDAN         5
# 10         AQUITANIA    CAMPERO   CHEVROLET   1989   CABINADO         5
# 11         AQUITANIA    CAMPERO  MITSUBISHI   1992   CABINADO         5
# 12         AQUITANIA  CAMIONETA   CHEVROLET   2004     ESTACA         2
# 13         AQUITANIA  CAMIONETA   CHEVROLET   1993     ESTACA         0
#
#       servicio  estado        linea tonelaje cilindraje blindaje importado  \
# 2   PARTICULAR  ACTIVO          626        0       2000        N         N
# 10  PARTICULAR  ACTIVO      TROOPER        0       2600        N         N
# 11  PARTICULAR  ACTIVO      MONTERO        0       2600        N         N
# 12  PARTICULAR  ACTIVO  LUV TFR LWB        1       2500        N         N
# 13  PARTICULAR  ACTIVO      LUV TFR        1          1        N         N
#
#    puertas
# 2        4
# 10       2
# 11       2
# 12       2
# 13       2

# %%
df_auto.pivot_table(values='modelo', index='municipio', columns=['servicio'], aggfunc='count')
# Out:
# servicio          OFICIAL  PARTICULAR
# municipio
# ACUERDOS DE PAGO      NaN         1.0
# AQUITANIA             1.0        24.0
# BOYACA                NaN         1.0
# CHIQUINQUIRA          3.0       479.0

# %%
df_auto.groupby(df_auto['municipio']).count()[['importado']]
# Out:
#                   importado
# municipio
# ACUERDOS DE PAGO          1
# AQUITANIA                25
# BOYACA                    1
# CHIQUINQUIRA            482

# %%
df_auto.groupby(df_auto['municipio']).count()['marca']
# Out:
# municipio
# ACUERDOS DE PAGO      1
# AQUITANIA            25
# BOYACA                1
# CHIQUINQUIRA        482
# Name: marca, dtype: int64

# %%
lis=list(df_auto['municipio'])
for i in lis:
  print(i)

# %%
#Punto 10 
#Todas las graficas deben ser explicadas
#Diagrama de Barras
categoria=['AUTO','CAM','CAMI','CAMIO', 'MOTO','VOL','BUS','MICRO']
plt.bar(categoria,aux,width=0.8, color='silver')
plt.xlabel('Clases')
plt.ylabel('Veces que se repiten')
plt.title('Análisi sobre las clases de automotores')
plt.grid()
plt.show()

# %% [markdown]
# **Análsis de la grafica**
#
#
#
# *   Se evidencia que la categoria de campero es la predoiminante con mas de 140 regitros
# *   La segunda categoria predominante es el automovil con 121 registros
# * La categoria con menor registro es el micro bus, el cual tiene un solo registro

# %% [markdown]
# **Analisis desde Chat GPT**
#
# El tipo de vehículo más común en la tabla es el "campero" con un total de 144 unidades registradas, seguido por los "automóviles" con 121 unidades y las "motocicletas" con 119 unidades.
#
# Los "camiones" y las "volquetas" tienen una presencia mucho menor en comparación con los otros tipos de vehículos. Hay solo 18 camiones y 7 volquetas registradas.
#
# Los "buses" y los "microbuses" tienen una presencia muy limitada en esta muestra de datos, con solo 3 buses y 1 microbús registrados.

# %%
print(aux)
print(categoria)
# Out:
# [121, 144, 96, 18, 119, 7, 3, 1]
# ['AUTO', 'CAM', 'CAMI', 'CAMIO', 'MOTO', 'VOL', 'BUS', 'MICRO']

# %%
#Graficas el diagrama de caja de los modelos
plt.boxplot(modelo_a)
plt.title('Diagrama de caja para el modelo')
plt.ylabel('Años')
plt.grid()
plt.show()

# %% [markdown]
# Este diagrama muestra que en los eqipos registrados la mayor proporción de concetración de vehiculo son modelo 1994, lo cual indica que el parque automotor tiene una edad alrededor de los 30 años. Las implicaciones de esta medida afecatan en varios escenarios por ejemplo:
# 1. El medio ambiente, ya que la emisión de gases afecta de manera negativa
# 2. La seguridad de los usuarios en vehiculos de uso publico.
# 3. La capacidad de transito de los vehiculos.
#
# Según la grafica, se observa que aún existe vehiculos de la dedaca del 50. Se deja abierto la posibilidad de analisis de estos vehiculos para conocer si son vehiculos de exibición o de uso particular.

# %%
#Grafica del histograma de modelos
plt.hist(modelo_a, bins=10)
plt.axvline(np.mean(modelo_a), ymin=0.0, ymax=0.9,color='r')
plt.title('Histograma de los modelos del parque automotor')
plt.grid()
plt.show()

# %% [markdown]
# En el histograma que representa los diferente modelos de automotores en la data set, se encuenra que la concentración de modelos esta al rededor de la decada de los 90. Esto implica que se debe tener un proposito de recambio del parque automotor en el desapartamento de Boyaca. Los posobles beneficios de este recambio pueden tener un impacto positivo en la economia, ya que se pueden activar varios frentes comerciales.
